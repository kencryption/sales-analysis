# %% [markdown]
# # Feature Engineering for Profit Prediction
#
# Now we prepare the dataset for machine learning by creating new features and transforming categorical variables.
#
# Goal: Construct a dataset suitable for predicting profit and optimizing discount strategies.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../data/raw/superstore.csv", encoding="latin1")

# %% [markdown]
# ## Conversion Of Date Columns

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ## Create Time Features

# %%
df['Shipping Time'] = (df['Ship Date'] - df['Order Date']).dt.days
df['Month'] = df['Order Date'].dt.month
df['Year'] = df['Order Date'].dt.year
df["Day Of Week"] = df["Order Date"].dt.dayofweek

# %% [markdown]
# ## Pricing Features

# %%
df["Item Price"] = df["Sales"] / df["Quantity"]

# %%
df["Profit Margin"] = df["Profit"] / df["Sales"]

# %% [markdown]
# ## Order Size Features

# %%
df["Value Per Item"] = df["Sales"] / df["Quantity"]

# %%
df["Discount Amount"] = df["Sales"] * df["Discount"]

# %% [markdown]
# ## Feature Selection

# %%
df.describe()
# Out:
#             Row ID                  Order Date                   Ship Date  \
# count  9994.000000                        9994                        9994
# mean   4997.500000  2016-04-30 00:07:12.259355  2016-05-03 23:06:58.571142
# min       1.000000         2014-01-03 00:00:00         2014-01-07 00:00:00
# 25%    2499.250000         2015-05-23 00:00:00         2015-05-27 00:00:00
# 50%    4997.500000         2016-06-26 00:00:00         2016-06-29 00:00:00
# 75%    7495.750000         2017-05-14 00:00:00         2017-05-18 00:00:00
# max    9994.000000         2017-12-30 00:00:00         2018-01-05 00:00:00
# std    2885.163629                         NaN                         NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit  \
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 30 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Row ID           9994 non-null   int64
#  1   Order ID         9994 non-null   str
#  2   Order Date       9994 non-null   datetime64[us]
#  3   Ship Date        9994 non-null   datetime64[us]
#  4   Ship Mode        9994 non-null   str
#  5   Customer ID      9994 non-null   str
#  6   Customer Name    9994 non-null   str
#  7   Segment          9994 non-null   str
#  8   Country          9994 non-null   str
#  9   City             9994 non-null   str
#  10  State            9994 non-null   str
#  11  Postal Code      9994 non-null   int64
#  12  Region           9994 non-null   str
#  13  Product ID       9994 non-null   str
#  14  Category         9994 non-null   str
#  15  Sub-Category     9994 non-null   str
#  16  Product Name     9994 non-null   str
# ...

# %%
features = [
    "Sales",
    "Quantity",
    "Discount",
    "Shipping Time",
    "Month",
    "Year",
    "Day Of Week",
    "Unit Price",
    "Item Price",
    "Value Per Item",
    "Discount Amount",
    "Ship Mode",
    "Segment",
    "Category",
    "Sub-Category",
    "Region"
]

target = "Profit"

# %%
df_model = df[features + [target]].copy()

# %%
df_model.head()
# Out:
#       Sales  Quantity  Discount  Shipping Time  Month  Year  Day Of Week  \
# 0  261.9600         2      0.00              3     11  2016            1
# 1  731.9400         3      0.00              3     11  2016            1
# 2   14.6200         2      0.00              4      6  2016            6
# 3  957.5775         5      0.45              7     10  2015            6
# 4   22.3680         2      0.20              7     10  2015            6
#
#    Unit Price  Item Price  Value Per Item  Discount Amount       Ship Mode  \
# 0    130.9800    130.9800        130.9800         0.000000    Second Class
# 1    243.9800    243.9800        243.9800         0.000000    Second Class
# 2      7.3100      7.3100          7.3100         0.000000    Second Class
# 3    191.5155    191.5155        191.5155       430.909875  Standard Class
# 4     11.1840     11.1840         11.1840         4.473600  Standard Class
#
#      Segment         Category Sub-Category Region    Profit
# ...

# %%
df_model.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sales            9994 non-null   float64
#  1   Quantity         9994 non-null   int64
#  2   Discount         9994 non-null   float64
#  3   Shipping Time    9994 non-null   int64
#  4   Month            9994 non-null   int32
#  5   Year             9994 non-null   int32
#  6   Day Of Week      9994 non-null   int32
#  7   Unit Price       9994 non-null   float64
#  8   Item Price       9994 non-null   float64
#  9   Value Per Item   9994 non-null   float64
#  10  Discount Amount  9994 non-null   float64
#  11  Ship Mode        9994 non-null   str
#  12  Segment          9994 non-null   str
#  13  Category         9994 non-null   str
#  14  Sub-Category     9994 non-null   str
#  15  Region           9994 non-null   str
#  16  Profit           9994 non-null   float64
# ...
